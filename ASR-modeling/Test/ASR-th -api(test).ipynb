# %%
import requests
TOKEN = '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'

API_URL = "https://api-inference.huggingface.co/models/DylanonWic/wav2vec2-large-asr-th"
headers = {"Authorization": f"Bearer {TOKEN}"}

def query(filename):
    with open(filexname, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

output = query("sample1.flac")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-01770dece3d2> in <module>
#      10     return response.json()
#      11
# ---> 12 output = query("sample1.flac")
#
# <ipython-input-1-01770dece3d2> in query(filename)
#       5
#       6 def query(filename):
# ----> 7     with open(filename, "rb") as f:
#       8         data = f.read()
#       9     response = requests.post(API_URL, headers=headers, data=data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample1.flac'
